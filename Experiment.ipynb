# %%
from parser import Parser
from demoparser2 import DemoParser

parser = Parser("heroic-vs-3dmax-m1-dust2.dem")

parser.parse()
# Out:
# Considering heroic-vs-3dmax-m1-dust2.dem
#   Found 4 rounds with bomb defusions!
#   Parsed round 5
#   Parsed round 10
#   Parsed round 13
#   Parsed round 14
# [['Middle',
#   'Catwalk',
#   'ShortStairs',
#   'ExtendedA',
#   'ShortStairs',
#   'ExtendedA',
#   'BombsiteA',
#   'UnderA',
#   'LongA',
#   'ARamp',
#   'Round End'],
#  ['MidDoors',
#   'Middle',
#   'Catwalk',
#   'ShortStairs',
#   'ExtendedA',
#   'BombsiteA',
#   'Round End'],
#  ['CTSpawn', 'UnderA', 'Die', 'Round End'],
#  ['CTSpawn', 'UnderA', 'LongA', 'ARamp', 'BombsiteA', 'Round End'],
#  ['CTSpawn',
#   'UnderA',
#   'LongA',
#   'ARamp',
#   'BombsiteA',
#   'ExtendedA',
#   'UnderA',
#   'ExtendedA',
#   'UnderA',
#   'ExtendedA',
#   'BombsiteA',
#   'ExtendedA',
#   'UnderA',
#   'CTSpawn',
#   'MidDoors',
#   'Round End'],
#  ['Middle',
#   'LowerTunnel',
#   'TunnelStairs',
#   'UpperTunnel',
#   'BombsiteB',
#   'Die',
#   'Round End'],
#  ['Middle',
#   'LowerTunnel',
#   'TunnelStairs',
# ...

# %%
asd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 asd
#
# NameError: name 'asd' is not defined

# %%
parser: DemoParser = DemoParser("heroic-vs-3dmax-m1-dust2.dem")
parser_attributes = ["total_rounds_played"]
events_bomb_defused = parser.parse_event(
    "bomb_defused", other=parser_attributes
)
events_bomb_planted = parser.parse_event(
    "bomb_planted", other=parser_attributes
)

# %%
events_bomb_defused

# %%
events_bomb_planted

# %%
events_bomb_planted[
    events_bomb_planted["total_rounds_played"] == 5
    ].iloc[0]['tick']

# %%
events_bomb_defused[
    events_bomb_planted["total_rounds_played"] == 5
].iloc[0]
